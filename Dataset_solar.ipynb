# %% [markdown]
# <a href="https://colab.research.google.com/github/cascaschatz/Solar_PCL/blob/master/Dataset_solar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
cwd = os.getcwd()
print(cwd)
os.chdir("/content/gdrive/My Drive")
# Out:
# /content

# %%
import pandas as pd
df_wb = pd.read_csv(r'Solar_std_t.csv')
df_generation = pd.read_excel(r'generation.xlsx', engine='openpyxl')
df_consumption = pd.read_excel(r'consumption.xlsx', engine='openpyxl')
df_capacity = pd.read_excel(r'capacity.xlsx', engine='openpyxl')

# %%
#df_wb.tail(700)
df_wb.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-060334f15877> in <module>
#       1 #df_wb.tail(700)
# ----> 2 df_wb.shape()
#
# TypeError: 'tuple' object is not callable

# %%
#df_capacity.head(60)
df_capacity['Megawatts'] = df_capacity['Megawatts']. replace(['US'],['United States'])
df_generation['Terawatt-hours'] = df_generation['Terawatt-hours']. replace(['US'],['United States'])
df_consumption['Exajoules (input-equivalent)'] = df_consumption['Exajoules (input-equivalent)']. replace(['US'],['United States'])

# %%
df_generation.head()
# Out:
#   Terawatt-hours  Year  Value
# 0         Canada  1965    0.0
# 1         Mexico  1965    0.0
# 2  United States  1965    0.0
# 3      Argentina  1965    0.0
# 4         Brazil  1965    0.0

# %%
df_consumption.tail(96)
# Out:
#      Exajoules (input-equivalent)  Year     Value
# 5148                       Taiwan  2020  0.057434
# 5149                     Thailand  2020  0.048787
# 5150                      Vietnam  2020  0.102677
# 5151           Other Asia Pacific  2020  0.010500
# 5152                       Canada  2021  0.048624
# ...                           ...   ...       ...
# 5239                    Sri Lanka  2021  0.007171
# 5240                       Taiwan  2021  0.074609
# 5241                     Thailand  2021  0.049384
# 5242                      Vietnam  2021  0.242758
# 5243           Other Asia Pacific  2021  0.014074
#
# [96 rows x 3 columns]

# %%
df_capacity.rename(columns = {'Megawatts':'Country Name', 'Value':'Capacity'}, inplace = True)
df_generation.rename(columns = {'Terawatt-hours':'Country Name', 'Value':'Generation'}, inplace = True)
df_consumption = df_consumption.rename(columns = {'Exajoules':'Country Name', 'Value':'Consumption'})

# %%
df_capacity.head()
# Out:
#     Country Name  Year  Capacity
# 0         Canada  1996       3.0
# 1         Mexico  1996      10.0
# 2  United States  1996      13.9
# 3      Argentina  1996       0.0
# 4         Brazil  1996       0.0

# %%
df_generation.head()
# Out:
#     Country Name  Year  Generation
# 0         Canada  1965         0.0
# 1         Mexico  1965         0.0
# 2  United States  1965         0.0
# 3      Argentina  1965         0.0
# 4         Brazil  1965         0.0

# %%
df_generation["Unnamed: 0"] = df_generation["Country Name"] + df_generation["Year"].astype(str)

# %%
df_generation
# Out:
#             Country Name  Year  Generation              Unnamed: 0
# 0                 Canada  1965    0.000000              Canada1965
# 1                 Mexico  1965    0.000000              Mexico1965
# 2          United States  1965    0.000000       United States1965
# 3              Argentina  1965    0.000000           Argentina1965
# 4                 Brazil  1965    0.000000              Brazil1965
# ...                  ...   ...         ...                     ...
# 5239           Sri Lanka  2021    0.761211           Sri Lanka2021
# 5240              Taiwan  2021    7.920296              Taiwan2021
# 5241            Thailand  2021    5.242457            Thailand2021
# 5242             Vietnam  2021   25.770420             Vietnam2021
# 5243  Other Asia Pacific  2021    1.494088  Other Asia Pacific2021
#
# [5244 rows x 4 columns]

# %%
df_wb.head()
# Out:
#           Unnamed: 0  \
# 0         Canada2012
# 1         Mexico2012
# 2  United States2012
# 3      Argentina2012
# 4         Brazil2012
#
#    Access.to.clean.fuels.and.technologies.for.cooking....of.population.  \
# 0                                           0.491605
# 1                                          -0.369865
# 2                                           0.491605
# 3                                           0.463635
# 4                                           0.195125
#
#    Access.to.electricity....of.population.  \
# 0                                 0.305146
# 1                                 0.135476
# 2                                 0.305146
# 3                                 0.158079
# 4                                 0.213373
#
#    Adolescent.fertility.rate..births.per.1.000.women.ages.15.19.  \
# 0                                          -0.543171
# 1                                           1.934452
# ...

# %%
df_merged1 = pd.merge(df_generation, df_wb, on = ['Unnamed: 0'])

# %%
df_merged1
# Out:
#       Country Name  Year  Generation         Unnamed: 0  \
# 0           Canada  2012    0.880807         Canada2012
# 1           Mexico  2012    0.069000         Mexico2012
# 2    United States  2012    9.037014  United States2012
# 3        Argentina  2012    0.008173      Argentina2012
# 4           Brazil  2012    0.000980         Brazil2012
# ..             ...   ...         ...                ...
# 555    Philippines  2019    1.246082    Philippines2019
# 556      Singapore  2019    0.194619      Singapore2019
# 557      Sri Lanka  2019    0.500400      Sri Lanka2019
# 558       Thailand  2019    5.146000       Thailand2019
# 559        Vietnam  2019    5.251790        Vietnam2019
#
#      Access.to.clean.fuels.and.technologies.for.cooking....of.population.  \
# 0                                             0.491605
# 1                                            -0.369865
# 2                                             0.491605
# ...

# %%
df_merged2 = pd.merge(df_capacity, df_merged1, on = ['Country Name','Year'])

# %%
df_merged = pd.merge(df_merged2, df_generation)

# %%
df_merged1.to_csv('/content/gdrive/My Drive/dataset_solar.csv',index = True)

# %%
df_used=df_merged1.loc[df_merged1['Year'] >= 2012]

# %%
df_used2=df_used.loc[df_merged1['Year'] <2020]

# %%
Report_Card.loc[:,["Lectures","Grades"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f8a8241349fd> in <module>()
# ----> 1 Report_Card.loc[:,["Lectures","Grades"]]
#
# NameError: name 'Report_Card' is not defined

# %%
df_used2
# Out:
#       Country Name  Year  Generation         Unnamed: 0  \
# 0           Canada  2012    0.880807         Canada2012
# 1           Mexico  2012    0.069000         Mexico2012
# 2    United States  2012    9.037014  United States2012
# 3        Argentina  2012    0.008173      Argentina2012
# 4           Brazil  2012    0.000980         Brazil2012
# ..             ...   ...         ...                ...
# 555    Philippines  2019    1.246082    Philippines2019
# 556      Singapore  2019    0.194619      Singapore2019
# 557      Sri Lanka  2019    0.500400      Sri Lanka2019
# 558       Thailand  2019    5.146000       Thailand2019
# 559        Vietnam  2019    5.251790        Vietnam2019
#
#      Access.to.clean.fuels.and.technologies.for.cooking....of.population.  \
# 0                                             0.491605
# 1                                            -0.369865
# 2                                             0.491605
# ...

# %% [markdown]
# df_final=df_used2.loc[:,['Country Name','Year','Access to clean fuels and technologies for cooking (% of population)','Access to electricity (% of population)','Adolescent fertility rate (births per 1,000 women ages 15-19)','Adolescents out of school (% of lower secondary school age)','Age dependency ratio (% of working-age population)','Agricultural land (% of land area)','Air transport, passengers carried','Alternative and nuclear energy (% of total energy use)','Armed forces personnel (% of total labor force)','Average precipitation in depth (mm per year)','Average time to clear exports through customs (days)','Birth rate, crude (per 1,000 people)','Borrowers from commercial banks (per 1,000 adults)','Bribery incidence (% of firms experiencing at least one bribe payment request)','Central government debt, total (current LCU)','Children out of school (% of primary school age)','CO2 emissions (kt)','Commercial bank branches (per 100,000 adults)','Compulsory education, duration (years)','Consumer price index (2010 = 100)','Coverage of social insurance programs (% of population)','Current health expenditure per capita (current US$)','Death rate, crude (per 1,000 people)','Ease of doing business score (0 = lowest performance to 100 = best performance)','Electric power consumption (kWh per capita)','Electric power transmission and distribution losses (% of output)','Electricity production from coal sources (% of total)','Electricity production from hydroelectric sources (% of total)','Electricity production from natural gas sources (% of total)','Electricity production from nuclear sources (% of total)','Electricity production from oil sources (% of total)','Electricity production from oil, gas and coal sources (% of total)','Electricity production from renewable sources, excluding hydroelectric (% of total)','Electricity production from renewable sources, excluding hydroelectric (kWh)','Energy use (kg of oil equivalent per capita)','Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)','Exports of goods and services (annual % growth)','Female share of employment in senior and middle management (%)','Fertility rate, total (births per woman)','Final consumption expenditure (current US$)','Firms expected to give gifts in meetings with tax officials (% of firms)','Firms experiencing electrical outages (% of firms)','Food production index (2014-2016 = 100)','Foreign direct investment, net (BoP, current US$)','Forest area (sq. km)','Fossil fuel energy consumption (% of total)','GDP (current US$)','GDP per capita (current US$)','General government final consumption expenditure (current US$)','Gini index','Goods exports (BoP, current US$)','Goods imports (BoP, current US$)','Gross savings (current US$)','HFC gas emissions (thousand metric tons of CO2 equivalent)','High-technology exports (current US$)','Hospital beds (per 1,000 people)','Households and NPISHs Final consumption expenditure (current US$)','Human capital index (HCI) (scale 0-1)','Individuals using the Internet (% of population)','Inflation, consumer prices (annual %)','Investment in energy with private participation (current US$)','Labor force, total','Land area (sq. km)','Life expectancy at birth, total (years)','Military expenditure (current USD)','Mobile cellular subscriptions','Multidimensional poverty index (scale 0-1)','Net migration','Net trade in goods (BoP, current US$)','New businesses registered (number)','Patent applications, nonresidents','Patent applications, residents','People practicing open defecation (% of population)','People using at least basic drinking water services (% of population)','Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)','Population in urban agglomerations of more than 1 million','Population, total','Procedures to build a warehouse (number)','Procedures to register property (number)','Pump price for diesel fuel (US$ per liter)','Pump price for gasoline (US$ per liter)','Renewable electricity output (% of total electricity output)','Renewable energy consumption (% of total final energy consumption)','Research and development expenditure (% of GDP)','Rural land area (sq. km)','Rural population','Sex ratio at birth (male births per female births)','Strength of legal rights index (0=weak to 12=strong)','Suicide mortality rate (per 100,000 population)','Surface area (sq. km)','Time required to get electricity (days)','Unemployment, total (% of total labor force) (modeled ILO estimate)','Unemployment, total (% of total labor force) (national estimate)','Urban land area (sq. km)','Urban population','Value lost due to electrical outages (% of sales for affected firms)','Wanted fertility rate (births per woman)','Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)','Generation']]

# %%
cols = list(df_used2.columns.values)
cols
# Out:
# ['Country Name',
#  'Year',
#  'Generation',
#  'Unnamed: 0',
#  'Access.to.clean.fuels.and.technologies.for.cooking....of.population.',
#  'Access.to.electricity....of.population.',
#  'Adolescent.fertility.rate..births.per.1.000.women.ages.15.19.',
#  'Age.dependency.ratio....of.working.age.population.',
#  'Air.transport..passengers.carried',
#  'Armed.forces.personnel....of.total.labor.force.',
#  'Birth.rate..crude..per.1.000.people.',
#  'Commercial.bank.branches..per.100.000.adults.',
#  'Compulsory.education..duration..years.',
#  'Consumer.price.index..2010...100.',
#  'Current.health.expenditure.per.capita..current.US..',
#  'Death.rate..crude..per.1.000.people.',
#  'Exports.of.goods.and.services..annual...growth.',
#  'Fertility.rate..total..births.per.woman.',
#  'Final.consumption.expenditure..current.US..',
#  'Food.production.index..2014.2016...100.',
#  'Foreign.direct.investment..net..BoP..current.US..',
#  'Forest.area..sq..km.',
#  'GDP..current.US..',
# ...

# %%
import jupytext

# %%
# !jupytext --to markdown Dataset_solar.ipynb
# Out:
# [jupytext] Reading Dataset_solar.ipynb in format ipynb
# [jupytext] Writing Dataset_solar.md

# %%
import os
os.chdir("/content/gdrive/MyDrive/Colab Notebooks")
# !ls
# Out:
#  BibBD.ipynb				     Dataset_solar.ipynb
#  Bible_complete_2.ipynb			     gne.csv
#  Bible_completo.ipynb			    'model_emotions_final (1).ipynb'
#  Bible.ipynb				    'model_emotions_final (2).ipynb'
#  BPstats.ipynb				    'model_emotions_final (3).ipynb'
# 'Cópia de Dataset_solar.ipynb'		     model_emotions_final.ipynb
# 'Copy of C2W2_Assignment.ipynb'		     Untitled
# 'Copy of C2W3_Assignment.ipynb'		     Untitled0.ipynb
# 'Copy of Copy of World_bank_dataset.ipynb'   Untitled1.ipynb
# 'Copy of World_bank_dataset.ipynb'	     World_bank_dataset.ipynb

# %%
pip install jupytext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 297 kB 7.0 MB/s
# ...
#      |████████████████████████████████| 84 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 46 kB 4.8 MB/s
# ...

# %%
df_used3= df_used2[[
 'Access.to.clean.fuels.and.technologies.for.cooking....of.population.',
 'Access.to.electricity....of.population.',
 'Adolescent.fertility.rate..births.per.1.000.women.ages.15.19.',
 'Age.dependency.ratio....of.working.age.population.',
 'Air.transport..passengers.carried',
 'Armed.forces.personnel....of.total.labor.force.',
 'Birth.rate..crude..per.1.000.people.',
 'Commercial.bank.branches..per.100.000.adults.',
 'Compulsory.education..duration..years.',
 'Consumer.price.index..2010...100.',
 'Current.health.expenditure.per.capita..current.US..',
 'Death.rate..crude..per.1.000.people.',
 'Exports.of.goods.and.services..annual...growth.',
 'Fertility.rate..total..births.per.woman.',
 'Final.consumption.expenditure..current.US..',
 'Food.production.index..2014.2016...100.',
 'Foreign.direct.investment..net..BoP..current.US..',
 'Forest.area..sq..km.',
 'GDP..current.US..',
 'GDP.per.capita..current.US..',
 'General.government.final.consumption.expenditure..current.US..',
 'Gini.index',
 'Goods.exports..BoP..current.US..',
 'Goods.imports..BoP..current.US..',
 'Gross.savings..current.US..',
 'High.technology.exports..current.US..',
 'Hospital.beds..per.1.000.people.',
 'Households.and.NPISHs.Final.consumption.expenditure..current.US..',
 'Individuals.using.the.Internet....of.population.',
 'Inflation..consumer.prices..annual...',
 'Labor.force..total',
 'Land.area..sq..km.',
 'Life.expectancy.at.birth..total..years.',
 'Military.expenditure..current.USD.',
 'Mobile.cellular.subscriptions',
 'Net.trade.in.goods..BoP..current.US..',
 'New.businesses.registered..number.',
 'Patent.applications..nonresidents',
 'Patent.applications..residents',
 'People.practicing.open.defecation....of.population.',
 'People.using.at.least.basic.drinking.water.services....of.population.',
 'Population.in.urban.agglomerations.of.more.than.1.million',
 'Population..total',
 'Procedures.to.build.a.warehouse..number.',
 'Procedures.to.register.property..number.',
 'Renewable.energy.consumption....of.total.final.energy.consumption.',
 'Research.and.development.expenditure....of.GDP.',
 'Rural.population',
 'Sex.ratio.at.birth..male.births.per.female.births.',
 'Surface.area..sq..km.',
 'Time.required.to.get.electricity..days.',
 'Unemployment..total....of.total.labor.force...modeled.ILO.estimate.',
 'Unemployment..total....of.total.labor.force...national.estimate.',
 'Urban.population','Generation']]

# %%
df_used3
# Out:
#      Access.to.clean.fuels.and.technologies.for.cooking....of.population.  \
# 0                                             0.491605
# 1                                            -0.369865
# 2                                             0.491605
# 3                                             0.463635
# 4                                             0.195125
# ..                                                 ...
# 555                                          -2.501165
# 556                                           0.491605
# 557                                          -3.390605
# 558                                          -0.476151
# 559                                          -1.499846
#
#      Access.to.electricity....of.population.  \
# 0                                   0.305146
# 1                                   0.135476
# 2                                   0.305146
# 3                                   0.158079
# 4                                   0.213373
# ...

# %%
#df_final=df_used2.loc[:,'Country Name','Year','Access to clean fuels and technologies for cooking (% of population)','Access to electricity (% of population)','Adolescent fertility rate (births per 1,000 women ages 15-19)','Adolescents out of school (% of lower secondary school age)','Age dependency ratio (% of working-age population)','Agricultural land (% of land area)','Air transport, passengers carried','Alternative and nuclear energy (% of total energy use)','Armed forces personnel (% of total labor force)','Average precipitation in depth (mm per year)','Average time to clear exports through customs (days)','Birth rate, crude (per 1,000 people)','Borrowers from commercial banks (per 1,000 adults)','Bribery incidence (% of firms experiencing at least one bribe payment request)','Central government debt, total (current LCU)','Children out of school (% of primary school age)','CO2 emissions (kt)','Commercial bank branches (per 100,000 adults)','Compulsory education, duration (years)','Consumer price index (2010 = 100)','Coverage of social insurance programs (% of population)','Current health expenditure per capita (current US$)','Death rate, crude (per 1,000 people)','Ease of doing business score (0 = lowest performance to 100 = best performance)','Electric power consumption (kWh per capita)','Electric power transmission and distribution losses (% of output)','Electricity production from coal sources (% of total)','Electricity production from hydroelectric sources (% of total)','Electricity production from natural gas sources (% of total)','Electricity production from nuclear sources (% of total)','Electricity production from oil sources (% of total)','Electricity production from oil, gas and coal sources (% of total)','Electricity production from renewable sources, excluding hydroelectric (% of total)','Electricity production from renewable sources, excluding hydroelectric (kWh)','Energy use (kg of oil equivalent per capita)','Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)','Exports of goods and services (annual % growth)','Female share of employment in senior and middle management (%)','Fertility rate, total (births per woman)','Final consumption expenditure (current US$)','Firms expected to give gifts in meetings with tax officials (% of firms)','Firms experiencing electrical outages (% of firms)','Food production index (2014-2016 = 100)','Foreign direct investment, net (BoP, current US$)','Forest area (sq. km)','Fossil fuel energy consumption (% of total)','GDP (current US$)','GDP per capita (current US$)','General government final consumption expenditure (current US$)','Gini index','Goods exports (BoP, current US$)','Goods imports (BoP, current US$)','Gross savings (current US$)','HFC gas emissions (thousand metric tons of CO2 equivalent)','High-technology exports (current US$)','Hospital beds (per 1,000 people)','Households and NPISHs Final consumption expenditure (current US$)','Human capital index (HCI) (scale 0-1)','Individuals using the Internet (% of population)','Inflation, consumer prices (annual %)','Investment in energy with private participation (current US$)','Labor force, total','Land area (sq. km)','Life expectancy at birth, total (years)','Military expenditure (current USD)','Mobile cellular subscriptions','Multidimensional poverty index (scale 0-1)','Net migration','Net trade in goods (BoP, current US$)','New businesses registered (number)','Patent applications, nonresidents','Patent applications, residents','People practicing open defecation (% of population)','People using at least basic drinking water services (% of population)','Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)','Population in urban agglomerations of more than 1 million','Population, total','Procedures to build a warehouse (number)','Procedures to register property (number)','Pump price for diesel fuel (US$ per liter)','Pump price for gasoline (US$ per liter)','Renewable electricity output (% of total electricity output)','Renewable energy consumption (% of total final energy consumption)','Research and development expenditure (% of GDP)','Rural land area (sq. km)','Rural population','Sex ratio at birth (male births per female births)','Strength of legal rights index (0=weak to 12=strong)','Suicide mortality rate (per 100,000 population)','Surface area (sq. km)','Time required to get electricity (days)','Unemployment, total (% of total labor force) (modeled ILO estimate)','Unemployment, total (% of total labor force) (national estimate)','Urban land area (sq. km)','Urban population','Value lost due to electrical outages (% of sales for affected firms)','Wanted fertility rate (births per woman)','Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)','Generation']

# %%
#df_final2=df_used2.loc[:,['Country Name','Year','Access to clean fuels and technologies for cooking (% of population)','Access to electricity (% of population)','Adolescent fertility rate (births per 1,000 women ages 15-19)','Age dependency ratio (% of working-age population)','Air transport, passengers carried','Armed forces personnel (% of total labor force)','Birth rate, crude (per 1,000 people)','Commercial bank branches (per 100,000 adults)','Compulsory education, duration (years)','Consumer price index (2010 = 100)','Current health expenditure per capita (current US$)','Death rate, crude (per 1,000 people)','Exports of goods and services (annual % growth)','Fertility rate, total (births per woman)','Final consumption expenditure (current US$)','Food production index (2014-2016 = 100)','Foreign direct investment, net (BoP, current US$)','Forest area (sq. km)','GDP (current US$)','GDP per capita (current US$)','General government final consumption expenditure (current US$)','Gini index','Goods exports (BoP, current US$)','Goods imports (BoP, current US$)','Gross savings (current US$)','High-technology exports (current US$)','Hospital beds (per 1,000 people)','Households and NPISHs Final consumption expenditure (current US$)','Individuals using the Internet (% of population)','Inflation, consumer prices (annual %)','Labor force, total','Land area (sq. km)','Life expectancy at birth, total (years)','Military expenditure (current USD)','Mobile cellular subscriptions','Net trade in goods (BoP, current US$)','New businesses registered (number)','Patent applications, nonresidents','Patent applications, residents','People practicing open defecation (% of population)','People using at least basic drinking water services (% of population)','Population in urban agglomerations of more than 1 million','Population, total','Procedures to build a warehouse (number)','Procedures to register property (number)','Renewable energy consumption (% of total final energy consumption)','Research and development expenditure (% of GDP)','Rural population','Sex ratio at birth (male births per female births)','Surface area (sq. km)','Time required to get electricity (days)','Unemployment, total (% of total labor force) (modeled ILO estimate)','Unemployment, total (% of total labor force) (national estimate)','Urban population','Generation']]

# %%
df_final3=df_final2.fillna(df_final2.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
df_used2.to_csv('/content/gdrive/My Drive/data_solar3.csv',index = True)

# %%
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# Create arrays for the features and the target: X, y
X, y = df_used3.iloc[:,:-1], df_used2.iloc[:,-1]

# Create the training and test sets
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=123)

# Create the own optimized data structure for datasets called a DMatrix
DM_train = xgb.DMatrix(data=X_train, label=y_train)
DM_test  = xgb.DMatrix(data=X_test, label=y_test)


# Create the parameter dictionary: params
params = {"booster":"gblinear", "objective":"reg:linear"}

# Train the model: xg_reg
xg_reg = xgb.train(params = params, dtrain=DM_train, num_boost_round=100)


# Predict the labels of the test set: preds
preds = xg_reg.predict(DM_test)

# Compute and print the RMSE
rmse = np.sqrt(mean_squared_error(y_test,preds))
print("RMSE: %f" % (rmse))

# Compute the accuracy: accuracy
# accuracy = float(np.sum(preds==y_test))/y_test.shape[0]
# print("accuracy: %f" % (accuracy))
# Out:
# [23:25:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE: 0.038297

# %%
# Create the DMatrix: housing_dmatrix
housing_dmatrix = xgb.DMatrix(X,y)

# Create the parameter dictionary: params
params = {"objective":"reg:squarederror","max_depth":4}

# Train the model: xg_reg
xg_reg = xgb.train(params=params, dtrain=housing_dmatrix, num_boost_round=10000)

# Plot the feature importances
xgb.plot_importance(xg_reg)
#plt.rcParams['figure.figsize'] = [50,10]
#plt.show()

# %%
xg_reg.get_score(importance_type='weight')

# %%
feature_important = xg_reg.get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(55, columns="score").plot(kind='barh', figsize = (20,10)) ## plot top 40 features
